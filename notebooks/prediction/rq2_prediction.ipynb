# %% [markdown]
# # RQ2. Which practices deliver the most substantial security returns?

# %%
import numpy as np
import pandas as pd
import polars as pl
import polars.selectors as cs
import seaborn as sns
from settings import load_settings
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline
from matplotlib import pyplot as plt
from capstone import construct_final_dataset as fd

# %%
settings = load_settings()
df = pl.read_parquet(settings.research_question_2_dataset_path)

# %%
df.head()
# Out:
# shape: (5, 22)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────────┬───────────┬──────┬──────────┐
# │ package_na ┆ github_rep ┆ package_de ┆ package_to ┆ … ┆ security_p ┆ vul_count ┆ mttr ┆ mttu     │
# │ me         ┆ o          ┆ pendency_c ┆ tal_downlo ┆   ┆ olicy      ┆ ---       ┆ ---  ┆ ---      │
# │ ---        ┆ ---        ┆ ount       ┆ ads        ┆   ┆ ---        ┆ i64       ┆ f64  ┆ f64      │
# │ str        ┆ str        ┆ ---        ┆ ---        ┆   ┆ i64        ┆           ┆      ┆          │
# │            ┆            ┆ u32        ┆ i64        ┆   ┆            ┆           ┆      ┆          │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════════╪═══════════╪══════╪══════════╡
# │ s3manifest ┆ machu-gwu/ ┆ 2          ┆ 2648       ┆ … ┆ 0          ┆ 0         ┆ null ┆ null     │
# │ o          ┆ s3manifest ┆            ┆            ┆   ┆            ┆           ┆      ┆          │
# │            ┆ o-project  ┆            ┆            ┆   ┆            ┆           ┆      ┆          │
# │ deepteam   ┆ confident- ┆ 8          ┆ 205459     ┆ … ┆ 0          ┆ 0         ┆ null ┆ null     │
# │            ┆ ai/deeptea ┆            ┆            ┆   ┆            ┆           ┆      ┆          │
# │            ┆ m          ┆            ┆            ┆   ┆            ┆           ┆      ┆          │
# │ volosti-co ┆ volosti/vo ┆ 5          ┆ 23         ┆ … ┆ 0          ┆ 0         ┆ null ┆ null     │
# │ mmon       ┆ losti-comm ┆            ┆            ┆   ┆            ┆           ┆      ┆          │
# │            ┆ on         ┆            ┆            ┆   ┆            ┆           ┆      ┆          │
# │ polyfit    ┆ dschmitz89 ┆ 3          ┆ 87339      ┆ … ┆ 0          ┆ 10        ┆ null ┆ null     │
# │            ┆ /polyfit   ┆            ┆            ┆   ┆            ┆           ┆      ┆          │
# │ tinyshare  ┆ youruserna ┆ 3          ┆ 20896      ┆ … ┆ null       ┆ null      ┆ 0.0  ┆ 2.238036 │
# │            ┆ me/tinysha ┆            ┆            ┆   ┆            ┆           ┆      ┆          │
# │            ┆ re         ┆            ┆            ┆   ┆            ┆           ┆      ┆          │
# └────────────┴────────────┴────────────┴────────────┴───┴────────────┴───────────┴──────┴──────────┘
