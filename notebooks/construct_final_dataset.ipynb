# %%
from settings import load_settings
from capstone.construct_final_dataset import FinalDatasetConstructor

# %%
SETTINGS = load_settings()

# %%
construct = FinalDatasetConstructor()

# %%
final_dataset = construct()

# %%
final_dataset.describe()

# %%
final_dataset.drop_nulls().describe()
